# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarohi098/Lesson-1/blob/main/calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
 num1 = float(input("Enter a number"))
except ValueError as ex:
  print("Error", ex)

try:
 num2 = float(input("Enter another number"))
except ValueError as ex:
 print("Error", ex)
function = input("Enter the operation you want to do: a, s, m or d ").lower()

def addition(num1, num2):
    return(num1 + num2)
def subtraction(num1, num2):
    return(num1 - num2)
def multiplication(num1, num2):
    return(num1 * num2)
def division(num1, num2):
    try:
      return(num1/ num2)
    except ZeroDivisionError as ex:
      print("Error" , ex)
      print("Please don't enter the second number as zero")



if function == "a":
  print(addition(num1, num2))
elif function == "s":
  print(subtraction(num1, num2))
elif function == "m":
  print(multiplication(num1, num2))
elif function == "d":
  print(division(num1, num2))
